# %% [markdown]
# ![alt text](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTK4gQ9nhwHHaSXMHpeggWg7twwMCgb877smkRmtkmDeDoGF9Z6&usqp=CAU)

# %% [markdown]
# ![](https://cienciadosdados.com/images/Montanha_Estdio_Fotogrfico_Capa_para_Facebook.png)

# %% [markdown]
# #  <font color='Blue'> Análise Exploratória dos Dados</font>

# %% [markdown]
# # Dicionário de Dados
# ![](https://cienciadosdados.com/images/2022/AD.png)

# %% [markdown]
# # Conexão com os Dados
# ![](https://i2.wp.com/www.aceql.com/wp-content/uploads/2021/08/AceQL-Schema-min.jpg?ssl=1)

# %%
# Conexão com os Dados
import pandas as pd
df = pd.read_excel('/content/clientes_investimentos.xlsx')
df
# Out:
#            cliente  poupanca   cdb  renda  segmentacao  seguro
# 0      537044639.0       312  1288  49002         40.0     1.0
# 1      876520833.0       340  5892  32696         13.0     1.0
# 2      881113910.0       520  2526   8855         40.0     1.0
# 3      891866209.0       832  7314  60821         40.0     1.0
# 4      810003285.0      1293  8593  23508         40.0     0.0
# ...            ...       ...   ...    ...          ...     ...
# 32556  816950489.0      1223    34  90663         38.0     0.0
# 32557  806707803.0       543  1940  12632         40.0     1.0
# 32558  730303105.0       324  3590  63919         40.0     0.0
# 32559  770056517.0        76  6566  36798         20.0     1.0
# 32560  716298220.0       766  3269  46517         40.0     0.0
#
# [32561 rows x 6 columns]

# %%
# verificar dimensões do dataset
df.shape
# Out:
# (32561, 6)

# %%
# Informações sobre as variáveis
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cliente      32561 non-null  float64
#  1   poupanca     32561 non-null  int64
#  2   cdb          32561 non-null  int64
#  3   renda        32561 non-null  int64
#  4   segmentacao  32561 non-null  float64
#  5   seguro       32561 non-null  float64
# dtypes: float64(3), int64(3)
# memory usage: 1.5 MB

# %%
# Verifica valores missing (ausentes , nulos)
df.isnull().sum()
# Out:
# cliente        0
# poupanca       0
# cdb            0
# renda          0
# segmentacao    0
# seguro         0
# dtype: int64

# %%
# Verifica valores duplicados
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Análise Estatística
# ![](https://qph.fs.quoracdn.net/main-qimg-da056fb5f41719bd37c30f7631b79782-lq)

# %%
# Estatística Descritiva das variáveis numéricas do Dataset
df.describe()
# Out:
#             cliente      poupanca           cdb         renda   segmentacao  \
# count  3.256100e+04  32561.000000  32561.000000  32561.000000  32561.000000
# mean   8.002490e+08    754.564755   5007.776788  52576.389331     40.437456
# std    5.757900e+07    433.078250   2884.511248  27424.158265     12.347429
# min    5.370446e+08     11.000000      1.000000   5007.000000      1.000000
# 25%    7.506786e+08    378.000000   2518.000000  28821.000000     40.000000
# 50%    8.003224e+08    755.000000   5028.000000  52561.000000     40.000000
# 75%    8.503749e+08   1131.000000   7501.000000  76163.000000     45.000000
# max    8.999989e+08   1500.000000  10000.000000  99999.000000     99.000000
#
#              seguro
# count  32561.000000
# mean       0.669205
# std        0.470506
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
# Frequencia das variáveis categoricas (que possuem ao invés de uma sequencia de números, possuem categorias a, b, c...)
df['seguro'].value_counts()
# Out:
# 1.0    21790
# 0.0    10771
# Name: seguro, dtype: int64

# %%
# Criação de Campos 
df['invest_total'] = df['poupanca'] + df['cdb']
df
# Out:
#            cliente  poupanca   cdb  renda  segmentacao  seguro  invest_total
# 0      537044639.0       312  1288  49002         40.0     1.0          1600
# 1      876520833.0       340  5892  32696         13.0     1.0          6232
# 2      881113910.0       520  2526   8855         40.0     1.0          3046
# 3      891866209.0       832  7314  60821         40.0     1.0          8146
# 4      810003285.0      1293  8593  23508         40.0     0.0          9886
# ...            ...       ...   ...    ...          ...     ...           ...
# 32556  816950489.0      1223    34  90663         38.0     0.0          1257
# 32557  806707803.0       543  1940  12632         40.0     1.0          2483
# 32558  730303105.0       324  3590  63919         40.0     0.0          3914
# 32559  770056517.0        76  6566  36798         20.0     1.0          6642
# 32560  716298220.0       766  3269  46517         40.0     0.0          4035
#
# [32561 rows x 7 columns]

# %%
df.corr(method='spearman')
# Out:
#                cliente  poupanca       cdb     renda  segmentacao    seguro  \
# cliente       1.000000 -0.007309 -0.007107 -0.006160     0.004825  0.003920
# poupanca     -0.007309  1.000000 -0.003331 -0.001235     0.001161 -0.002554
# cdb          -0.007107 -0.003331  1.000000 -0.006298    -0.000746  0.007212
# renda        -0.006160 -0.001235 -0.006298  1.000000    -0.002455  0.007247
# segmentacao   0.004825  0.001161 -0.000746 -0.002455     1.000000  0.264941
# seguro        0.003920 -0.002554  0.007212  0.007247     0.264941  1.000000
# invest_total -0.008040  0.140226  0.989391 -0.006312    -0.000779  0.006846
#
#               invest_total
# cliente          -0.008040
# poupanca          0.140226
# cdb               0.989391
# renda            -0.006312
# segmentacao      -0.000779
# seguro            0.006846
# invest_total      1.000000

# %%
import seaborn as sns
ax = sns.heatmap(df.corr(method='pearson'))

# %% [markdown]
# # Criação de Campos para Aprofundar a Análise
# ![](https://j.gifs.com/RoxQGO.gif)

# %%
# Criação de Campos 
df['perc_cdb'] = df['cdb'] / df['invest_total']
df
# Out:
#            cliente  poupanca   cdb  renda  segmentacao  seguro  invest_total  \
# 0      537044639.0       312  1288  49002         40.0     1.0          1600
# 1      876520833.0       340  5892  32696         13.0     1.0          6232
# 2      881113910.0       520  2526   8855         40.0     1.0          3046
# 3      891866209.0       832  7314  60821         40.0     1.0          8146
# 4      810003285.0      1293  8593  23508         40.0     0.0          9886
# ...            ...       ...   ...    ...          ...     ...           ...
# 32556  816950489.0      1223    34  90663         38.0     0.0          1257
# 32557  806707803.0       543  1940  12632         40.0     1.0          2483
# 32558  730303105.0       324  3590  63919         40.0     0.0          3914
# 32559  770056517.0        76  6566  36798         20.0     1.0          6642
# 32560  716298220.0       766  3269  46517         40.0     0.0          4035
#
#        perc_cdb
# 0      0.805000
# 1      0.945443
# 2      0.829284
# 3      0.897864
# 4      0.869209
# ...         ...
# 32556  0.027049
# 32557  0.781313
# 32558  0.917220
# 32559  0.988558
# 32560  0.810161
#
# [32561 rows x 8 columns]

# %% [markdown]
# # Realização de Filtros
# ![](https://i.gifer.com/origin/46/4645b5c1b28b702694757fcd99a4ec6d.gif)

# %%
#filtrando registros do dataset com loc
df.loc[df.renda > 99990]
# Out:
#            cliente  poupanca   cdb  renda  segmentacao  seguro  invest_total  \
# 4968   745335138.0      1427  7849  99998         50.0     1.0          9276
# 8597   842006314.0       615  3800  99994         40.0     1.0          4415
# 25922  874467515.0      1469   555  99999         40.0     1.0          2024
# 30382  793615862.0       573   401  99995         52.0     1.0           974
#
#        perc_cdb
# 4968   0.846162
# 8597   0.860702
# 25922  0.274209
# 30382  0.411704

# %%
#filtrando registros do dataset com loc
df.loc[df.perc_cdb > 0.98]
# Out:
#            cliente  poupanca   cdb  renda  segmentacao  seguro  invest_total  \
# 6      744840078.0       104  9994   7679         16.0     0.0         10098
# 41     804542270.0        24  5008  81378         40.0     1.0          5032
# 66     890632045.0        17  1254  99552         40.0     0.0          1271
# 85     882285895.0        77  8595  23252         35.0     0.0          8672
# 90     786262548.0        15  1250  52603         40.0     1.0          1265
# ...            ...       ...   ...    ...          ...     ...           ...
# 32490  838184534.0        47  6930   8553         35.0     1.0          6977
# 32521  730244116.0        46  6312  55710         40.0     1.0          6358
# 32545  865829262.0        61  8697  81233         20.0     0.0          8758
# 32549  872597289.0        61  6840  87053         40.0     0.0          6901
# 32559  770056517.0        76  6566  36798         20.0     1.0          6642
#
#        perc_cdb
# 6      0.989701
# 41     0.995231
# 66     0.986625
# 85     0.991121
# 90     0.988142
# ...         ...
# 32490  0.993264
# 32521  0.992765
# 32545  0.993035
# 32549  0.991161
# 32559  0.988558
#
# [2084 rows x 8 columns]

# %%
df.loc[(df.renda > 90000) & (df.perc_cdb > 0.98)]

# %%
#iloc: selecionando pela faixa de ´indice de 2 até 10 (10 é exclusivo)
df.iloc[0:10]

# %% [markdown]
# # Análise Gráfica
# ![](https://raw.githubusercontent.com/infinum/flutter-charts/feature/render-object/assets/showcase.gif)

# %%
# importar o Sns
import seaborn as sns
# Visualização Gráfica dos dados
sns.catplot(x="seguro", kind="count",  data=df);

# %%
# Visualização Gráfica dos dados
sns.boxplot(x="renda",   data=df);

# %%
# Visualização Gráfica dos dados
sns.distplot(df.perc_cdb	, kde=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##Fim

# %% [markdown]
# # Clique e Faça sua [Inscrição](https://cientistadedadosnapratica.com.br/inscrever-org-mar22) na Jornada Ciência de Dados
#
# ![](https://cienciadosdados.com/images/thumbs/seta-laranja.png)

# %% [markdown]
# # Links das Redes Sociais Ciência dos Dados
#
# # [LinkTree](https://linktr.ee/cienciadosdados)

# %%
from IPython.core.display import HTML
HTML('<iframe width="460" height="260" src="https://www.youtube.com/embed/0SL8XfuS-Ig" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="460" height="260" src="https://www.youtube.com/embed/0SL8XfuS-Ig" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
